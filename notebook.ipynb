# %%
import os
from pathlib import Path
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings('ignore', category=FutureWarning)

# Directorios de Entrada y Salida
DATA_DIR = Path('data')
OUTPUT_DIR = Path('datasets_procesados')

# Crear la carpeta de salida si no existe
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)


def limpiar_y_estandarizar_df(df):
    """
    Aplica reglas de limpieza estructural estricta:
    - Elimina filas vacías.
    - Limpia espacios en blanco en columnas y textos.
    - Convierte booleanos a enteros/texto limpio.
    """
    if df.empty:
        return df

    # 1. Eliminar filas completamente vacías
    df = df.dropna(how='all')

    # 2. Limpiar espacios en blanco en los nombres de las columnas
    df.columns = [str(col).strip() for col in df.columns]

    # 3. Limpiar celdas de texto (quitar espacios sobrantes al inicio y final)
    for col in df.select_dtypes(include=['object', 'string']).columns:
        df[col] = df[col].astype(str).str.strip()

    # 4. Convertir columnas booleanas (True/False) a enteros (1/0) o cadenas estandarizadas
    for col in df.select_dtypes(include=['bool']).columns:
        df[col] = df[col].astype(int)

    # 5. Reemplazar valores nulos representados como 'nan', 'null', 'none' por vacíos limpios o NaN oficial
    df = df.replace(to_replace=['nan', 'NaN', 'null', 'NULL', 'None', 'none'], value=np.nan)

    return df


def unificar_carpeta(nombre_fuente, separador_default=';', id_duplicados=None):
    """
    Busca todos los archivos en la carpeta correspondiente, los une y aplica limpieza estructural.
    """
    path_carpeta = DATA_DIR / nombre_fuente
    archivos = list(path_carpeta.glob('*.csv')) + list(path_carpeta.glob('*.xlsx'))

    print("\n" + "="*50)
    print(f"PROCESANDO Y UNIFICANDO ARCHIVOS DE: {nombre_fuente.upper()}")
    print("="*50)

    if not archivos:
        print(f"⚠️ No se encontraron archivos en: {path_carpeta}")
        return

    dfs = []
    print(f"📂 Encontrados {len(archivos)} archivos:")

    for archivo in archivos:
        print(f"  └─ Leyendo: {archivo.name}")
        try:
            if archivo.suffix == '.csv':
                try:
                    df = pd.read_csv(archivo, sep=separador_default, encoding='utf-8', low_memory=False)
                except Exception:
                    df = pd.read_csv(archivo, sep=',', encoding='utf-8-sig', low_memory=False)
            else:
                df = pd.read_excel(archivo)

            dfs.append(df)
        except Exception as e:
            print(f"  ❌ Error leyendo {archivo.name}: {e}")

    if not dfs:
        print("⚠️ No se pudieron procesar datos.")
        return

    # Unificación masiva
    df_unificado = pd.concat(dfs, ignore_index=True)
    filas_totales = len(df_unificado)

    # Limpieza estructural
    df_unificado = limpiar_y_estandarizar_df(df_unificado)

    # Deduplicación
    if id_duplicados and id_duplicados in df_unificado.columns:
        df_unificado = df_unificado.drop_duplicates(subset=[id_duplicados], keep='first')
    else:
        df_unificado = df_unificado.drop_duplicates(keep='first')

    filas_limpias = len(df_unificado)
    duplicados_eliminados = filas_totales - filas_limpias

    # Exportar archivo consolidado sin alterar la lógica de negocio
    ruta_salida = OUTPUT_DIR / f'dataset_{nombre_fuente.lower()}_unificado.csv'
    df_unificado.to_csv(ruta_salida, index=False, encoding='utf-8-sig')

    print(f"\n✅ Finalizado con éxito:")
    print(f"  • Filas totales consolidadas: {filas_totales}")
    print(f"  • Filas duplicadas omitidas: {duplicados_eliminados}")
    print(f"  • Total filas limpias guardadas: {filas_limpias}")
    print(f"📁 Guardado en: {ruta_salida}")


# ==========================================================
# EJECUCIÓN DEL PROCESO
# ==========================================================
if __name__ == '__main__':
    print("🚀 INICIANDO UNIFICACIÓN Y LIMPIEZA ESTRUCTURAL DE ARCHIVOS")

    # 1. VTEX (Ventas): Deduplica por la columna 'Order' si existe
    unificar_carpeta(nombre_fuente='VTEX', separador_default=';', id_duplicados='Order')

    # 2. META: Deduplica por filas idénticas
    unificar_carpeta(nombre_fuente='Meta', separador_default=',')

    # 3. GOOGLE: Deduplica por filas idénticas
    unificar_carpeta(nombre_fuente='Google', separador_default=',')

    print("\n" + "="*50)
    print("🎉 ¡TODOS LOS DATASETS FUERON UNIFICADOS Y LIMPIADOS EXITOSAMENTE!")
    print("="*50)
# Out:
# 🚀 INICIANDO UNIFICACIÓN Y LIMPIEZA ESTRUCTURAL DE ARCHIVOS
#
# ==================================================
# PROCESANDO Y UNIFICANDO ARCHIVOS DE: VTEX
# ==================================================
# 📂 Encontrados 9 archivos:
#   └─ Leyendo: Reporte 30-jun-2026-31-jul-2026.csv
#   └─ Leyendo: Reporte 31-dic-2025-2-jul-2025.csv
#   └─ Leyendo: Reporte 1-ene-2025-1-oct-2024.csv
#   └─ Leyendo: Reporte 1-jul-2025-2-ene-2025.csv
#   └─ Leyendo: Reporte 30-sep-2024-1-jul-2024.csv
#   └─ Leyendo: Reporte 1-ene-2026-29-jun-2026.csv
#   └─ Leyendo: Reporte 30-jul-2023-1-mar-2023.csv
#   └─ Leyendo: Reporte 30-jun-2024-1-ene-2024.csv
#   └─ Leyendo: Reporte 31-dic-2023-31-jul-2023.csv
#
# ✅ Finalizado con éxito:
#   • Filas totales consolidadas: 122328
#   • Filas duplicadas omitidas: 79776
#   • Total filas limpias guardadas: 42552
# 📁 Guardado en: datasets_procesados/dataset_vtex_unificado.csv
#
# ==================================================
# PROCESANDO Y UNIFICANDO ARCHIVOS DE: META
# ==================================================
# 📂 Encontrados 1 archivos:
#   └─ Leyendo: Ventas Meta jun-1-2023-al-jul-1-2026.csv
#
# ✅ Finalizado con éxito:
#   • Filas totales consolidadas: 1116
#   • Filas duplicadas omitidas: 0
#   • Total filas limpias guardadas: 1116
# 📁 Guardado en: datasets_procesados/dataset_meta_unificado.csv
#
# ==================================================
# PROCESANDO Y UNIFICANDO ARCHIVOS DE: GOOGLE
# ==================================================
# 📂 Encontrados 1 archivos:
#   └─ Leyendo: Ventas Google jun-1-2026.csv
#
# ✅ Finalizado con éxito:
#   • Filas totales consolidadas: 1051
#   • Filas duplicadas omitidas: 0
#   • Total filas limpias guardadas: 1051
# 📁 Guardado en: datasets_procesados/dataset_google_unificado.csv
#
# ==================================================
# 🎉 ¡TODOS LOS DATASETS FUERON UNIFICADOS Y LIMPIADOS EXITOSAMENTE!
# ==================================================

# %%
import pandas as pd
from pathlib import Path

OUTPUT_DIR = Path('datasets_procesados')

# Configuración explícita de Pandas para NO recortar ninguna columna
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 1000)

archivos_unificados = [
    'dataset_vtex_unificado.csv',
    'dataset_meta_unificado.csv',
    'dataset_google_unificado.csv'
]

for nombre_archivo in archivos_unificados:
    ruta_completa = OUTPUT_DIR / nombre_archivo
    
    print("\n" + "="*80)
    print(f"📄 AUDITORÍA COMPLETA: {nombre_archivo}")
    print("="*80)
    
    if not ruta_completa.exists():
        print(f"⚠️ El archivo {nombre_archivo} no existe en {OUTPUT_DIR}")
        continue
        
    df = pd.read_csv(ruta_completa, low_memory=False)
    
    filas, columnas = df.shape
    print(f"📊 Cantidad total de filas:    {filas:,}")
    print(f"📐 Cantidad total de columnas: {columnas}")
    print("-" * 80)
    
    # Construcción de la tabla resumen de TODAS las columnas
    info_cols = pd.DataFrame({
        'N°': range(1, columnas + 1),
        'Nombre de Columna': df.columns,
        'Tipo de Dato': df.dtypes.astype(str).values,
        'Valores Presentes': df.notnull().sum().values,
        'Valores Vacíos (NaN)': df.isnull().sum().values,
        '% Vacío': (df.isnull().sum().values / filas * 100).round(2)
    }).set_index('N°')
    
    # Imprimir la tabla completa de columnas sin omitir ninguna
    print(info_cols.to_string())
    print("-" * 80)

# Restablecer configuración por defecto de Pandas al terminar
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')
pd.reset_option('display.width')
# Out:
# ================================================================================
# 📄 AUDITORÍA COMPLETA: dataset_vtex_unificado.csv
# ================================================================================
# 📊 Cantidad total de filas:    42,552
# 📐 Cantidad total de columnas: 94
# --------------------------------------------------------------------------------
#                  Nombre de Columna Tipo de Dato  Valores Presentes  Valores Vacíos (NaN)  % Vacío
# N°
# 1                           Origin          str              42552                     0     0.00
# 2                            Order          str              42552                     0     0.00
# 3                         Sequence        int64              42552                     0     0.00
# 4                    Creation Date          str              42552                     0     0.00
# 5                      Client Name          str              42552                     0     0.00
# 6                 Client Last Name          str              42552                     0     0.00
# 7                  Client Document          str              42551                     1     0.00
# 8                            Email          str              42552                     0     0.00
# 9                            Phone          str              42471                    81     0.19
# 10                              UF          str              42552                     0     0.00
# 11                            City          str              42552                     0     0.00
# 12          Address Identification          str              42552                     0     0.00
# 13                    Address Type          str              42552                     0     0.00
# 14                   Receiver Name          str              42552                     0     0.00
# 15                          Street          str              42552                     0     0.00
# 16                          Number          str                 87                 42465    99.80
# 17                      Complement          str              37030                  5522    12.98
# 18                    Neighborhood          str              40110                  2442     5.74
# 19                       Reference          str                  3                 42549    99.99
# 20                     Postal Code          str              42552                     0     0.00
# 21                        SLA Type          str              42552                     0     0.00
# 22                        Courrier          str              42552                     0     0.00
# 23          Estimate Delivery Date          str              39476                  3076     7.23
# 24               Delivery Deadline          str              42552                     0     0.00
# 25                          Status          str              42552                     0     0.00
# 26                Last Change Date          str              42552                     0     0.00
# 27                       UtmMedium          str              15917                 26635    62.59
# 28                       UtmSource          str              18443                 24109    56.66
# 29                     UtmCampaign          str              15746                 26806    63.00
# 30                          Coupon          str               3170                 39382    92.55
# 31             Payment System Name          str              42549                     3     0.01
# 32                    Installments          str              42549                     3     0.01
# 33                   Payment Value          str              42549                     3     0.01
# 34                    Quantity_SKU        int64              42552                     0     0.00
# 35                          ID_SKU        int64              42552                     0     0.00
# 36                Category Ids Sku          str              42552                     0     0.00
# 37                  Reference Code          str              42550                     2     0.00
# 38                        SKU Name          str              42552                     0     0.00
# 39                       SKU Value        int64              42552                     0     0.00
# 40               SKU Selling Price        int64              42552                     0     0.00
# 41                 SKU Total Price        int64              42552                     0     0.00
# 42                        SKU Path          str              42552                     0     0.00
# 43                Item Attachments          str                 16                 42536    99.96
# 44                         List Id      float64                  0                 42552   100.00
# 45                  List Type Name      float64                  0                 42552   100.00
# 46  Service (Price/ Selling Price)      float64                  0                 42552   100.00
# 47             Shipping List Price        int64              42552                     0     0.00
# 48                  Shipping Value        int64              42552                     0     0.00
# 49                     Total Value        int64              42552                     0     0.00
# 50                Discounts Totals        int64              42552                     0     0.00
# 51                 Discounts Names          str              38563                  3989     9.37
# 52               Call Center Email      float64                  0                 42552   100.00
# 53                Call Center Code      float64                  0                 42552   100.00
# 54                 Tracking Number          str              39089                  3463     8.14
# 55                            Host          str              42552                     0     0.00
# 56                 GiftRegistry ID      float64                  0                 42552   100.00
# 57                     Seller Name          str              42552                     0     0.00
# 58                 Status TimeLine          str              42552                     0     0.00
# 59                             Obs          str                 36                 42516    99.92
# 60                        UtmiPart      float64                  0                 42552   100.00
# 61                    UtmiCampaign      float64                  0                 42552   100.00
# 62                        UtmiPage      float64                  0                 42552   100.00
# 63                 Seller Order Id      float64                  0                 42552   100.00
# 64                        Acquirer          str              26658                 15894    37.35
# 65                Authorization Id          str              39618                  2934     6.90
# 66                             TID          str              42332                   220     0.52
# 67                             NSU          str              20026                 22526    52.94
# 68               Card First Digits          str               4991                 37561    88.27
# 69                Card Last Digits          str               4991                 37561    88.27
# 70             Payment Approved By      float64                  0                 42552   100.00
# 71                    Cancelled By          str                101                 42451    99.76
# 72             Cancellation Reason          str                210                 42342    99.51
# 73                  Gift Card Name          str               1314                 41238    96.91
# 74               Gift Card Caption          str                  4                 42548    99.99
# 75                 Authorized Date          str              39467                  3085     7.25
# 76                  Corporate Name          str                 91                 42461    99.79
# 77              Corporate Document          str                 94                 42458    99.78
# 78                   TransactionId          str              42468                    84     0.20
# 79                       PaymentId          str              42438                   114     0.27
# 80                   PaymentOrigin      float64                  0                 42552   100.00
# 81                    SalesChannel        int64              42552                     0     0.00
# 82                   marketingTags          str              29380                 13172    30.96
# 83                       Delivered        int64              42552                     0     0.00
# 84                 SKU RewardValue        int64              42552                     0     0.00
# 85         Is Marketplace cetified       object                 84                 42468    99.80
# 86                   Is Checked In      float64                  0                 42552   100.00
# 87                   Currency Code          str              42552                     0     0.00
# 88                           Taxes      float64                  0                 42552   100.00
# 89                 Invoice Numbers          str              39396                  3156     7.42
# 90                         Country          str              42552                     0     0.00
# 91          Input Invoices Numbers          str              39396                  3156     7.42
# 92         Output Invoices Numbers          str                  1                 42551   100.00
# 93    Status raw value (temporary)          str              42552                     0     0.00
# 94               Cancellation Data          str                204                 42348    99.52
# --------------------------------------------------------------------------------
#
# ================================================================================
# 📄 AUDITORÍA COMPLETA: dataset_meta_unificado.csv
# ================================================================================
# 📊 Cantidad total de filas:    1,116
# 📐 Cantidad total de columnas: 22
# --------------------------------------------------------------------------------
#                                Nombre de Columna Tipo de Dato  Valores Presentes  Valores Vacíos (NaN)  % Vacío
# N°
# 1                                            Día          str               1116                     0     0.00
# 2                              Tipo de resultado      float64                  0                  1116   100.00
# 3                                     Resultados      float64                  0                  1116   100.00
# 4                            Costo por resultado      float64                  0                  1116   100.00
# 5                          Importe gastado (COP)        int64               1116                     0     0.00
# 6                                    Impresiones        int64               1116                     0     0.00
# 7                                        Alcance        int64               1116                     0     0.00
# 8                                     Frecuencia      float64               1116                     0     0.00
# 9                CPM (costo por mil impresiones)      float64               1111                     5     0.45
# 10                                       Compras      float64                561                   555    49.73
# 11                   Configuración de atribución          str               1116                     0     0.00
# 12                      Clasificación de calidad          str               1116                     0     0.00
# 13   Clasificación del porcentaje de interacción          str               1116                     0     0.00
# 14  Clasificación del porcentaje de conversiones          str               1116                     0     0.00
# 15               Nombre del conjunto de anuncios      float64                  0                  1116   100.00
# 16                               ROAS de compras      float64                556                   560    50.18
# 17                            Tasa de resultados      float64                  0                  1116   100.00
# 18                            Clics en el enlace      float64               1111                     5     0.45
# 19                Valor de conversión de compras      float64                561                   555    49.73
# 20                            Inicio del informe          str               1116                     0     0.00
# 21                               Fin del informe          str               1116                     0     0.00
# 22                        Resultados (iniciales)      float64                  0                  1116   100.00
# --------------------------------------------------------------------------------
#
# ================================================================================
# 📄 AUDITORÍA COMPLETA: dataset_google_unificado.csv
# ================================================================================
# 📊 Cantidad total de filas:    1,051
# 📐 Cantidad total de columnas: 7
# --------------------------------------------------------------------------------
#     Nombre de Columna Tipo de Dato  Valores Presentes  Valores Vacíos (NaN)  % Vacío
# N°
# 1                 Día          str               1051                     0      0.0
# 2               Impr.      float64               1051                     0      0.0
# 3               Clics      float64               1051                     0      0.0
# 4             Pedidos          str               1051                     0      0.0
# 5    Código de moneda          str               1051                     0      0.0
# 6               Coste          str               1051                     0      0.0
# 7   Valor conv./coste          str               1051                     0      0.0
# --------------------------------------------------------------------------------

# %%
from procesar_vtex_agrupado import generar_dataset_vtex_por_orden
generar_dataset_vtex_por_orden()
# Out:
# ============================================================
# PROCESANDO VTEX: AGRUPACIÓN A NIVEL DE ORDEN ÚNICA
# ============================================================
# 📂 Leyendo: dataset_vtex_unificado.csv...
# 📊 Total de ítems/filas iniciales: 42,552
# 🔄 Agrupando por 'Order'...
#
# ✅ Proceso completado exitosamente:
#   • Filas iniciales (ítems): 42,552
#   • Órdenes únicas finales: 42,552
# 📁 Guardado en: datasets_procesados/dataset_vtex_agrupado_ordenes.csv

# %%
import pandas as pd
from pathlib import Path

# Usamos la misma estructura de ruta que te funcionó
OUTPUT_DIR = Path('datasets_procesados')
ruta_vtex = OUTPUT_DIR / 'dataset_vtex_unificado.csv'

if ruta_vtex.exists():
    df = pd.read_csv(ruta_vtex, low_memory=False)
    
    # 1. Imprimir TODOS los registros de la columna UtmSource
    print("=== TODOS LOS RESULTADOS DE UtmSource ===")
    print(df['SKU Name'].unique())
else:
    print(f"⚠️ El archivo no existe en la ruta: {ruta_vtex.resolve()}")
# Out:
# === TODOS LOS RESULTADOS DE UtmSource ===
# <ArrowStringArray>
# [                    'Tinte #7.13 Rubio Avellana Green Code Kit 50g',
#                 'Tinte #8.0 Rubio Claro Natural Green Code Kit  50g',
#                     'Acondicionador Cabellos Secos Green Code 400ml',
#                             'Shampoo Vegan Keratin Collagen x1000ml',
#                  'Shampoo Color Intensifier Platinum SalonIn 1000ml',
#                                    'Firming Pomade Vitane Men 200 g',
#                                 'Shampoo Liss Control SalonIn 300ml',
#                                'Shampoo Rizos Perfectos Muss  400ml',
#                              'Protector Labial CHAPSTICK Minions x3',
#                              'Intens Mask Hydra Repair SalonIn 300g',
#  ...
#               'Espuma para Pies y Talones Cuarteados Deo Pies 60 ml',
#                               'Desodorante en Talco Deo Pies  150 g',
#                               'Tanga SPF 4 Crema Bronceador x 220ml',
#    'Jabón Líquido Antibacterial  Frutos Rojos Bacterion Fco. 300 ml',
#             'Jabón Líquido Antibacterial Bacterion D.Pack x 1000 ml',
#  'Tinte #10.0 Rubio Extra Claro Natural Green Forest Salon In 60 gr',
#                         'Tinte #8.01 Rubio Natural Cenizo Luminance',
#                       'VEGAN KERATIN COLLAGEN SHOT 12 DOSIS X 15 ML',
#           'Jabón Líquido Antibacterial  Bambú Bacterion Fco. 300 ml',
#   'Tanga SPF 60 Crema x 130 ml Tanga SPF 60 Crema x130 ml 297.1  ML']
# Length: 604, dtype: str

# %%
import os

print("Tu carpeta actual es:", os.getcwd())
print("Archivos/carpetas aquí:", os.listdir())
# Out:
# Tu carpeta actual es: /Users/richardacuna/Desktop/Analisis_TiendaCo
# Archivos/carpetas aquí: ['datasets_procesados', '.DS_Store', 'LICENSE', 'requirements.txt', 'notebook.ipynb', '__pycache__', 'README.md', 'etl_procesamiento.py', '.gitignore', 'procesar_vtex_agrupado.py', 'app.py', '.git', 'Data']

# %%
import pandas as pd
from pathlib import Path

DATASETS_DIR = Path('datasets_procesados')
META_PATH = DATASETS_DIR / 'dataset_meta_unificado.csv'
GOOGLE_PATH = DATASETS_DIR / 'dataset_google_unificado.csv'

print("="*60)
print("🔍 DIAGNÓSTICO DE DATASETS DE INVERSIÓN")
print("="*60)

# 1. Diagnóstico Meta
if META_PATH.exists():
    df_m = pd.read_csv(META_PATH, low_memory=False)
    print("\n📌 DATASET META:")
    print(f"  • Filas: {len(df_m):,}")
    print("  • Nombres de todas las columnas:")
    print(df_m.columns.tolist())
    print("\n  • Muestra de las primeras 3 filas:")
    display(df_m.head(3))
else:
    print("\n❌ No existe dataset_meta_unificado.csv")

# 2. Diagnóstico Google
if GOOGLE_PATH.exists():
    df_g = pd.read_csv(GOOGLE_PATH, low_memory=False)
    print("\n📌 DATASET GOOGLE:")
    print(f"  • Filas: {len(df_g):,}")
    print("  • Nombres de todas las columnas:")
    print(df_g.columns.tolist())
    print("\n  • Muestra de las primeras 3 filas:")
    display(df_g.head(3))
else:
    print("\n❌ No existe dataset_google_unificado.csv")
# Out:
# ============================================================
# 🔍 DIAGNÓSTICO DE DATASETS DE INVERSIÓN
# ============================================================
#
# 📌 DATASET META:
#   • Filas: 1,147
#   • Nombres de todas las columnas:
# ['Día', 'Estado de la entrega', 'Nivel de la entrega', 'Alcance', 'Impresiones', 'Frecuencia', 'Configuración de atribución', 'Tipo de resultado', 'Resultados', 'Importe gastado (COP)', 'Costo por resultado', 'Inicio', 'Finalización', 'Visitas a la página de destino', 'Clics en el enlace', 'Inicio del informe', 'Fin del informe', 'Resultados (iniciales)', 'CPM (costo por mil impresiones)', 'Compras', 'Clasificación de calidad', 'Clasificación del porcentaje de interacción', 'Clasificación del porcentaje de conversiones', 'Nombre del conjunto de anuncios', 'ROAS de compras', 'Tasa de resultados', 'Valor de conversión de compras']
#
#   • Muestra de las primeras 3 filas:
#           Día  Estado de la entrega  Nivel de la entrega  Alcance  \
# 0  2026-07-01                   NaN                  NaN    56476
# 1  2026-07-02                   NaN                  NaN    51546
# 2  2026-07-03                   NaN                  NaN    47205
#
#    Impresiones  Frecuencia           Configuración de atribución  \
# 0       112413    1.990456  Configuración de atribución múltiple
# 1        98983    1.920285  Configuración de atribución múltiple
# 2        97118    2.057367  Configuración de atribución múltiple
#
#    Tipo de resultado  Resultados  Importe gastado (COP)  ...  \
# 0                NaN         NaN                 935288  ...
# 1                NaN         NaN                 707293  ...
# 2                NaN         NaN                 664300  ...
#
#    Resultados (iniciales)  CPM (costo por mil impresiones)  Compras  \
# 0                     NaN                              NaN      NaN
# 1                     NaN                              NaN      NaN
# 2                     NaN                              NaN      NaN
#
#    Clasificación de calidad  Clasificación del porcentaje de interacción  \
# 0                       NaN                                          NaN
# 1                       NaN                                          NaN
# 2                       NaN                                          NaN
#
#   Clasificación del porcentaje de conversiones  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
#
#   Nombre del conjunto de anuncios  ROAS de compras  Tasa de resultados  \
# 0                             NaN              NaN                 NaN
# 1                             NaN              NaN                 NaN
# 2                             NaN              NaN                 NaN
#
#    Valor de conversión de compras
# 0                             NaN
# 1                             NaN
# 2                             NaN
#
# [3 rows x 27 columns]
# 📌 DATASET GOOGLE:
#   • Filas: 1,051
#   • Nombres de todas las columnas:
# ['Día', 'Impr.', 'Clics', 'Pedidos', 'Código de moneda', 'Coste', 'Valor conv./coste']
#
#   • Muestra de las primeras 3 filas:
#           Día    Impr.  Clics Pedidos Código de moneda     Coste  \
# 0  2023-01-01  403.000   29.0       0              COP     31868
# 1  2023-01-02   10.817  171.0       0              COP     32130
# 2  2023-01-03   14.489  302.0       0              COP  66562,29
#
#   Valor conv./coste
# 0                 0
# 1                 0
# 2                 0

# %%
import pandas as pd
from pathlib import Path

# 1. Cargar el dataset
ruta_dataset = Path('datasets_procesados/dataset_vtex_unificado.csv')
df = pd.read_csv(ruta_dataset, low_memory=False)

# 2. Nombre de la columna a revisar
columna = 'Status'

if columna in df.columns:
    # Obtener valores únicos eliminando valores nulos
    valores_unicos = df[columna].dropna().unique()
    
    print(f"Total de valores únicos en '{columna}': {len(valores_unicos)}\n")
    print("=" * 40)
    
    # Imprimir lista de valores únicos ordenados
    for valor in sorted(map(str, valores_unicos)):
        print(f"• {valor}")
        
    print("=" * 40)
    
    # OPCIONAL: Ver también el conteo/frecuencia de cada estado
    print("\nFrecuencia de cada valor:")
    print(df[columna].value_counts(dropna=False))

else:
    print(f"❌ La columna '{columna}' no existe en el DataFrame.")
# Out:
# Total de valores únicos en 'Status': 6
#
# ========================================
# • Aguardando despacho do seller
# • Cancelado
# • Faturado
# • Pagamento Pendente
# • Pronto para o manuseio
# • Verificando Fatura
# ========================================
#
# Frecuencia de cada valor:
# Status
# Faturado                         39393
# Cancelado                         3143
# Pagamento Pendente                  11
# Pronto para o manuseio               2
# Aguardando despacho do seller        2
# Verificando Fatura                   1
# Name: count, dtype: int64
